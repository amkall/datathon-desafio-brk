# %% [markdown]
# # Datathon BRK
# ## eficiencia operacional no saneamento

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Carregando dados

# %%
path = 'municipio.csv'
df = pd.read_csv(path, sep=";")

df.index = df.id_municipio
df.head()
# Out:
#              sigla_uf  id_municipio  populacao_urbana_2013  \
# id_municipio
# 1100015            RO       1100015                  14735
# 1100023            RO       1100023                  85770
# 1100031            RO       1100031                   2771
# 1100049            RO       1100049                  67665
# 1100056            RO       1100056                  15276
#
#               populacao_urbana_2035  \
# id_municipio
# 1100015                       15507
# 1100023                      121503
# 1100031                        3349
# 1100049                       80311
# 1100056                       14254
#
#                                  prestador_servico_esgoto sigla_prestador  \
# id_municipio
# 1100015                 Serviço Autônomo de Água e Esgoto            SAAE
# 1100023          Companhia de Águas e Esgotos de Rondônia           CAERD
# 1100031                    Prefeitura Municipal de Cabixi              PM
# 1100049       Serviço Autônomo de Água e Esgoto de Cacoal            SAAE
# 1100056                Prefeitura Municipal de Cerejeiras              PM
#
#              indice_sem_atend indice_atend_solucao_ind  \
# id_municipio
# 1100015                  96,7                      1,9
# 1100023                  89,4                      8,6
# 1100031                    99                      0,6
# 1100049                  28,8                     16,2
# 1100056                  79,6                     19,7
#
#              indice_atend_col_sem_trat indice_atend_col_trat  ...  \
# id_municipio                                                  ...
# 1100015                            1,4                     0  ...
# 1100023                              2                     0  ...
# 1100031                            0,4                     0  ...
# 1100049                              0                    55  ...
# 1100056                            0,7                     0  ...
#
#              populacao_atendida_2035 investimento_col investimento_trat  \
# id_municipio
# 1100015                        13956      16866794,48        4298529,94
# 1100023                       109353      119460468,9       25041739,67
# 1100031                         3014       4860355,53         690255,84
# 1100049                        72280      38921408,98         4891916,8
# 1100056                        12829      15623409,94        3951303,59
#
#              investimento_col_trat necessidade_remocao_dbo  \
# id_municipio
# 1100015                21165324,42            Acima de 80%
# 1100023                144502208,6          Entre 60 e 80%
# 1100031                 5550611,37          Entre 60 e 80%
# 1100049                43813325,77          Entre 60 e 80%
# 1100056                19574713,53            Acima de 80%
#
#                                tipologia_solucao atencao_fosforo  \
# id_municipio
# 1100015           Tratamento secundário avançado             Não
# 1100023       Tratamento secundário convencional             Não
# 1100031       Tratamento secundário convencional             Não
# 1100049       Tratamento secundário convencional             Não
# 1100056           Tratamento secundário avançado             Não
#
#              atencao_nitrogenio Unnamed: 40 Unnamed: 41
# id_municipio
# 1100015                     Não         NaN         NaN
# 1100023                     Não         NaN         NaN
# 1100031                     Não         NaN         NaN
# 1100049                     Não         NaN         NaN
# 1100056                     Não         NaN         NaN
#
# [5 rows x 42 columns]

# %% [markdown]
# ## Formatando dados para representação em grafico

# %%
df['investimento_col_trat'] = df['investimento_col_trat'].astype(str)
df['investimento_col_trat'] = df['investimento_col_trat'].str.replace(',', '.')

df['investimento_col_trat'] = df['investimento_col_trat'].astype(float)

df.head()
# Out:
#              sigla_uf  id_municipio  populacao_urbana_2013  \
# id_municipio
# 1100015            RO       1100015                  14735
# 1100023            RO       1100023                  85770
# 1100031            RO       1100031                   2771
# 1100049            RO       1100049                  67665
# 1100056            RO       1100056                  15276
#
#               populacao_urbana_2035  \
# id_municipio
# 1100015                       15507
# 1100023                      121503
# 1100031                        3349
# 1100049                       80311
# 1100056                       14254
#
#                                  prestador_servico_esgoto sigla_prestador  \
# id_municipio
# 1100015                 Serviço Autônomo de Água e Esgoto            SAAE
# 1100023          Companhia de Águas e Esgotos de Rondônia           CAERD
# 1100031                    Prefeitura Municipal de Cabixi              PM
# 1100049       Serviço Autônomo de Água e Esgoto de Cacoal            SAAE
# 1100056                Prefeitura Municipal de Cerejeiras              PM
#
#              indice_sem_atend indice_atend_solucao_ind  \
# id_municipio
# 1100015                  96,7                      1,9
# 1100023                  89,4                      8,6
# 1100031                    99                      0,6
# 1100049                  28,8                     16,2
# 1100056                  79,6                     19,7
#
#              indice_atend_col_sem_trat indice_atend_col_trat  ...  \
# id_municipio                                                  ...
# 1100015                            1,4                     0  ...
# 1100023                              2                     0  ...
# 1100031                            0,4                     0  ...
# 1100049                              0                    55  ...
# 1100056                            0,7                     0  ...
#
#              populacao_atendida_2035 investimento_col investimento_trat  \
# id_municipio
# 1100015                        13956      16866794,48        4298529,94
# 1100023                       109353      119460468,9       25041739,67
# 1100031                         3014       4860355,53         690255,84
# 1100049                        72280      38921408,98         4891916,8
# 1100056                        12829      15623409,94        3951303,59
#
#              investimento_col_trat necessidade_remocao_dbo  \
# id_municipio
# 1100015               2.116532e+07            Acima de 80%
# 1100023               1.445022e+08          Entre 60 e 80%
# 1100031               5.550611e+06          Entre 60 e 80%
# 1100049               4.381333e+07          Entre 60 e 80%
# 1100056               1.957471e+07            Acima de 80%
#
#                                tipologia_solucao atencao_fosforo  \
# id_municipio
# 1100015           Tratamento secundário avançado             Não
# 1100023       Tratamento secundário convencional             Não
# 1100031       Tratamento secundário convencional             Não
# 1100049       Tratamento secundário convencional             Não
# 1100056           Tratamento secundário avançado             Não
#
#              atencao_nitrogenio Unnamed: 40 Unnamed: 41
# id_municipio
# 1100015                     Não         NaN         NaN
# 1100023                     Não         NaN         NaN
# 1100031                     Não         NaN         NaN
# 1100049                     Não         NaN         NaN
# 1100056                     Não         NaN         NaN
#
# [5 rows x 42 columns]

# %% [markdown]
# ## Ordenando municipios por investimento

# %%
df.sort_values(['investimento_col_trat'], ascending = False, axis = 0, inplace = True)

df_inv = df.investimento_col_trat.head(20)

df
# Out:
#              sigla_uf  id_municipio  populacao_urbana_2013  \
# id_municipio
# 3304557            RJ       3304557                6429923
# 2304400            CE       2304400                2551806
# 3550308            SP       3550308               11715605
# 1302603            AM       1302603                1972131
# 5300108            DF       5300108                2694296
# ...               ...           ...                    ...
# 3550506            SP       3550506                   5372
# 3517802            SP       3517802                   6773
# 4120002            PR       4120002                  11453
# 5220058            GO       5220058                   1247
# 3170602            MG       3170602                   1170
#
#               populacao_urbana_2035  \
# id_municipio
# 3304557                     6901792
# 2304400                     3156422
# 3550308                    12219483
# 1302603                     2586905
# 5300108                     3859955
# ...                             ...
# 3550506                        6580
# 3517802                        6567
# 4120002                        9237
# 5220058                        1160
# 3170602                        1078
#
#                                        prestador_servico_esgoto  \
# id_municipio
# 3304557       Companhia Estadual de Águas e Esgotos / FAB Zo...
# 2304400                     Companhia de Água e Esgoto do Ceará
# 3550308       Companhia de Saneamento Básico do Estado de Sã...
# 1302603       Manaus Ambiental (SOLVI-PARTICIPAÇÕES EM PROJE...
# 5300108       Companhia de Saneamento Ambiental do Distrito ...
# ...                                                         ...
# 3550506                       Serviço Autônomo de Água e Esgoto
# 3517802       Autarquia Municipal de Saneamento Ambiental de...
# 4120002                       Companhia de Saneamento do Paraná
# 5220058                                 Saneamento de Goiás S/A
# 3170602                   Prefeitura Municipal de Vargem Bonita
#
#              sigla_prestador indice_sem_atend indice_atend_solucao_ind  \
# id_municipio
# 3304557        CEDAE / FABZO             13,8                      4,2
# 2304400               CAGECE              2,2                     36,8
# 3550308               SABESP             10,9                      1,7
# 1302603            MA (SAAB)             49,3                     22,1
# 5300108                CAESB              8,6                      8,3
# ...                      ...              ...                      ...
# 3550506                 SAAE                0                        0
# 3517802                  SAG                0                        0
# 4120002              SANEPAR              9,1                      0,6
# 5220058              SANEAGO                0                        0
# 3170602                   PM                0                        0
#
#              indice_atend_col_sem_trat indice_atend_col_trat  ...  \
# id_municipio                                                  ...
# 3304557                           15,8                  66,2  ...
# 2304400                              0                    61  ...
# 3550308                           21,9                  65,6  ...
# 1302603                              0                  28,6  ...
# 5300108                              0                  83,1  ...
# ...                                ...                   ...  ...
# 3550506                              0                   100  ...
# 3517802                              0                   100  ...
# 4120002                              0                  90,4  ...
# 5220058                              0                   100  ...
# 3170602                              0                   100  ...
#
#              populacao_atendida_2035 investimento_col investimento_trat  \
# id_municipio
# 3304557                      6211613       1010692498        1888248278
# 2304400                      3156422       1716607225       954498028,7
# 3550308                     10997535       1294713022        1321537475
# 1302603                      2328215       1910612292       602959080,8
# 5300108                      3473960       1304604860       397808269,1
# ...                              ...              ...               ...
# 3550506                         6580                0                 0
# 3517802                         6567                0                 0
# 4120002                         8349                0                 0
# 5220058                         1160                0                 0
# 3170602                         1078                0                 0
#
#              investimento_col_trat      necessidade_remocao_dbo  \
# id_municipio
# 3304557               2.898941e+09  Requer solução complementar
# 2304400               2.671105e+09  Requer solução complementar
# 3550308               2.616250e+09             Solução conjunta
# 1302603               2.513571e+09               Entre 60 e 80%
# 5300108               1.702413e+09                 Acima de 80%
# ...                            ...                          ...
# 3550506               0.000000e+00               Entre 60 e 80%
# 3517802               0.000000e+00               Entre 60 e 80%
# 4120002               0.000000e+00               Entre 60 e 80%
# 5220058               0.000000e+00               Entre 60 e 80%
# 3170602               0.000000e+00               Entre 60 e 80%
#
#                                               tipologia_solucao  \
# id_municipio
# 3304557       Outras soluções (revisão da classe do rio corp...
# 2304400       Outras soluções (revisão da classe do rio corp...
# 3550308                                        Solução conjunta
# 1302603                      Tratamento secundário convencional
# 5300108                          Tratamento secundário avançado
# ...                                                         ...
# 3550506                      Tratamento secundário convencional
# 3517802                      Tratamento secundário convencional
# 4120002                      Tratamento secundário convencional
# 5220058                      Tratamento secundário convencional
# 3170602                      Tratamento secundário convencional
#
#              atencao_fosforo atencao_nitrogenio Unnamed: 40 Unnamed: 41
# id_municipio
# 3304557                  Não                Não         NaN         NaN
# 2304400                  Não                Não         NaN         NaN
# 3550308                  Sim                Sim         NaN         NaN
# 1302603                  Não                Não         NaN         NaN
# 5300108                  Sim                Sim         NaN         NaN
# ...                      ...                ...         ...         ...
# 3550506                  Não                Não         NaN         NaN
# 3517802                  Não                Não         NaN         NaN
# 4120002                  Não                Não         NaN         NaN
# 5220058                  Não                Não         NaN         NaN
# 3170602                  Não                Não         NaN         NaN
#
# [5570 rows x 42 columns]

# %%
df_inv.plot(kind='bar')

plt.title("Municipios com o maior investimento em saneamento")
plt.ylabel("R$")

plt.show()

# %%
import seaborn as sns

# %%
sns.pairplot(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-e822a59c8b4a> in <module>
# ----> 1 sns.pairplot(df_inv)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    1970
#    1971     if not isinstance(data, pd.DataFrame):
# -> 1972         raise TypeError(
#    1973             "'data' must be pandas DataFrame object, not: {typefound}".format(
#    1974                 typefound=type(data)))
#
# TypeError: 'data' must be pandas DataFrame object, not: <class 'pandas.core.series.Series'>
